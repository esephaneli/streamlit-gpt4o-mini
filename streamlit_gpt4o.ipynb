# %% [markdown]
# <a href="https://colab.research.google.com/github/esephaneli/streamlit-gpt4o-mini/blob/main/streamlit_gpt4o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Streamlit + GPT-4o-mini Chatbot
#
# Bu notebook, Streamlit üzerinde geliştirilen bir chatbot uygulamasının
# temel mimarisini ve kritik kod yapılarını özetlemek amacıyla hazırlanmıştır.
#
# Amaç, token maliyetini bilinçli yöneten ve bağlamı koruyan bir chatbot
# tasarımını anlatmaktır.

# %%
SYSTEM_PROMPT = """
You are a helpful AI assistant.
You answer clearly and concisely.
"""

# %% [markdown]
# > Gerçek projede system prompt, mentör davranışı ve yönlendirici cevaplar
# > verecek şekilde daha detaylı tasarlanmıştır.

# %%
if "messages" not in st.session_state:
    st.session_state.messages = []

# %% [markdown]
# session_state sayesinde hafızayı tutarız ve konuşmaları özetleyen yapıya hakim oluruz.

# %%
def get_context(messages):
    return messages[-3:]

# %% [markdown]
# Bu yapı sayesinde tüm konuşma geçmişi yerine yalnızca en ilgili son mesajlar modele gönderilir.

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=context,
    max_tokens=300
)

# %% [markdown]
# Gerçek uygulamada, bu yapı sistem prompt ve konuşma özeti ile birlikte kullanılmaktadır.
